# %%
def kargers_alg(lista,graph):
    g= supervertex(graph)
    E1=

# %%
grafo={
    "A":["B","F","G"],
    "B":["A","F","G","E"],
    "C":["E","H","I","D"],
    "D":["C","H","I"],
    "E":["B","C","G","H","I"],
    "F":["A","B","G"],
    "G":["F","A","B","E"],
    "H":["E","C","D","I"],
    "I":["H","E","C","D"]
    
}

# %%
lista2=[]
for key in grafo:
    for k in grafo[key]:
        lista2.append({key,k})

# %%
listaaux=[]
for k in lista2:
    if k not in listaaux:
        listaaux.append(k)

# %%
listaaux
# Out:
# [{'A', 'B'},
#  {'B', 'F'},
#  {'B', 'G'},
#  {'B', 'E'},
#  {'F', 'G'},
#  {'A', 'G'},
#  {'E', 'G'},
#  {'C', 'E'},
#  {'C', 'H'},
#  {'C', 'I'},
#  {'C', 'D'},
#  {'E', 'H'},
#  {'E', 'I'},
#  {'H', 'I'},
#  {'D', 'I'},
#  {'D', 'H'},
#  {'A', 'F'}]

# %%
def supervertex(grafo):
    lista=[]
    for key in list(grafo):
        for k in key:
            lista.append({key,k})
    return lista

# %%
supervertex(grafo)
# Out:
# [{'B'}, {'G'}, {'C'}, {'E'}, {'I'}, {'H'}, {'F'}, {'D'}, {'A'}]

# %%
def lista(dic):
    for keys in dic:
