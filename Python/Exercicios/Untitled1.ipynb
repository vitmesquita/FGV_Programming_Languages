# %%
import random
import numpy as np

# %%
def vector(n):
    l=[]
    for i in range(n*100):
        a=random.randint(0,1000)
        l.append(a)
    return l

# %%
int main() {
	int B[]={9,6,2,10};
	int s=sizeof(B);
	vector<int> A;
	int j;
	for (j=0; j<s ; j++)
	A.push_back(A[j]);
	int n=sizeof(A);

	
	vector<int> R = insertsort(A,n);
   
    for(int i = 0; i<A.size(); i++){
       cout <<  A[i];
   }
     
   return 0;
# Out:
#   File "<ipython-input-4-8eaf9bb336c6>", line 1
#     int main() {
#            ^
# SyntaxError: invalid syntax

# %%
vector(3)

# %%
4*5
# Out:
# 20
