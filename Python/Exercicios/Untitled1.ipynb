# %%
import random
import numpy as np

# %%
def vector(n):
    l=[]
    for i in range(n*100):
        a=random.randint(0,1000)
        l.append(a)
    return l

# %%
int main() {
	int B[]={9,6,2,10};
	int s=sizeof(B);
	vector<int> A;
	int j;
	for (j=0; j<s ; j++)
	A.push_back(A[j]);
	int n=sizeof(A);

	
	vector<int> R = insertsort(A,n);
   
    for(int i = 0; i<A.size(); i++){
       cout <<  A[i];
   }
     
   return 0;

# %%
vector(2)
# Out:
# [485,
#  139,
#  123,
#  375,
#  280,
#  850,
#  885,
#  2,
#  227,
#  724,
#  387,
#  900,
#  86,
#  270,
#  823,
#  757,
#  311,
#  140,
#  741,
#  844,
#  221,
#  79,
#  636,
#  777,
#  804,
#  797,
#  428,
#  824,
#  593,
#  40,
#  78,
#  517,
#  994,
#  658,
#  60,
#  219,
#  283,
#  558,
#  913,
#  935,
#  41,
#  983,
#  406,
#  699,
#  549,
#  643,
#  421,
#  739,
#  497,
#  396,
#  819,
#  700,
#  623,
#  784,
#  460,
#  634,
#  280,
#  251,
#  397,
#  281,
#  96,
#  572,
#  92,
#  671,
#  986,
#  619,
#  949,
#  378,
#  907,
#  994,
#  940,
#  859,
#  66,
#  541,
#  693,
#  973,
#  446,
#  342,
#  210,
#  126,
#  506,
#  564,
#  416,
#  759,
#  837,
#  198,
#  564,
#  167,
#  65,
#  552,
#  286,
#  360,
#  350,
#  974,
#  368,
#  41,
#  35,
#  846,
#  985,
#  871,
#  346,
#  201,
#  929,
#  393,
#  921,
#  306,
#  734,
#  314,
#  764,
#  1,
#  58,
#  414,
#  568,
#  468,
#  530,
#  588,
#  52,
#  957,
#  483,
#  881,
#  657,
#  691,
#  973,
#  541,
#  754,
#  618,
#  204,
# ...
