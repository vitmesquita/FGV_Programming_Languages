# %%
graph={0:{1,2,3},
       1:{},
       2:{4,5,6},
       3:{6},
       4:{7},
       5:{7},
       6:{7},
       7:{}
      }

# %%
lista=[97]

# %%
sum(lista)
# Out:
# 97

# %%
len(graph)
# Out:
# 7

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def dfs(graph,u,visited=None):
    if visited == None:
        visited=set()
        
    visited.add(u)
    for v in graph[u]:
        if v not in visited:
            dfs(graph,v,visited)
    print(u)

# %%
dfs(graph,5,)
# Out:
# 1
# 2
# 4
# 3
# 7
# 6
# 5

# %%
def bfs(s,graph,visited=None):  
    if visited == None:
        visited=set()
    L=[]
    n=len(graph)
    for i in range(n):
        L[i]={}
    L[0]={s}
    for i in range(n):
        for y in L[i]:
            for v in graph[u]:
                if v not in visited:
                    visited.add(v)
                    L[i+1].add(v) 
    print(L)

# %%
bfs()

# %%
def g2(n,lista):
    s=0
    for i in range(n):
        for j in range(i):
            s=s+lista[i]*lista[j]
        print(s)
    return s

# %%
g2(3,[1,2,3])
# Out:
# 0
# 2
# 11
# 11

# %%
def g22(n,lista):
    s=0
    for i in range(n):
        s=s+lista[i]
    return s**2
