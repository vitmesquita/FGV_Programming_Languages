# %% [markdown]
# Project Euler - Problem 4

# %%
def problem4:
    lista=[]
    a=-1
    for numero1 in range(100,1000):
        for numero2 in range(100,999):
            p=numero1*numero2
            v=str(p)
            dig=len(v)
            for teste in range(int(dig/2)):
                if v[teste]==v[teste+a]:
                    a=a-1
                    continue
                else:
                    break
