# %%
def froghopping(lily,r):
    #lilu =[1,2,3,..]
    n=0
    H=[0]
    curlily={"index":0,"position":0}
    while curlily["position"]<lily[-1]:
        nextlily=furthest_reachable_lily(curlily,lily,r)
        H.append(nextlily["position"])
        curlily=nextlily
    return H

# %%
def furthest_reachable_lily(curlily,lily,r):
    nextlily=curlily["position"]+r

# %%
def furthest_reachable_lily(curlily,lily,r):
    nextlily=curlily+r
    while r>0:
        if nextlily in lily:
            return nextlily
        else:
            r=r-1
            nextlily=curlily+r
