# %%
Terça-feira 14-16h

# %%
B=[1,5,0,3,4,10,100,2]

# %%
http://web.stanford.edu/class/archive/cs/cs161/cs161.1138/

# %%
insertionsort2(B)
# Out:
# [0, 1, 2, 3, 4, 5, 10, 100]

# %%
def insertionsort2(A):
    for i in range(len(A)):
        valor=A[i]
        j=i-1
        while (j>0 or j==0) and A[j]>A[i]:
            A[j+1]=A[j]
            A[j]=valor
            j=j-1
            i=i-1
            
    print(A)

# %%
insertionsort2(A)
# Out:
# [0, 1, 3, 4, 5]

# %%
# C++ 'Hello World'

#include <iostream>

using namespace std;

int main() {
	cout << "Hello World!";
	return 0;
}

# %%
#insertionsort in C++

#include <iostream>
#include <vector>

using namespace std;

void insertsort(int A[],int n)
{    // usa void quando a funçao nao retorna nada
	int i,j,valor;
	
	for(int i=0; i<n; i++) 
	{
	
		valor=A[i];
		j=i-1;
	
		while (j>=0 && A[j]>A[i])
		{
			A[j+1]=A[j];
        	A[j]=valor;
        	j=j-1;
        	i=i-1;
		}
	}
}

void print(int A[], int n)
{
	int i;
	for (i=0; i<n ; i++) 

	printf("%d ",A[i]); 
   	printf("\n");
}

int main() {
	int A[]={9,6,2,10};
	int n = sizeof(A)/sizeof(A[0]);
	insertsort(A,n);
	print(A,n);
	
	return 0;
}

# %%
# fazendo um 3 2 1

#include <iostream>
#include <vector>

using namespace std;

void insertion(vector<int> vec){

}
void print(vector<int> v){    // usa void quando a funçao nao retorna nada
	for(int i=0; i<v.size(); i++){
		cout << v[i] << " ";
	}
	cout << endl;
}

int main() {
	vector<int> a;
	a.push_back(3);
	a.push_back(2);
	a.push_back(1);
	print(a);
	
	return 0;
}

# %%
formas de criar sequencias

vector<int> v;
list<int> l;
int array [100]


implementar insertionsort com essas estruturas 
com vetor randomico de 10k,20k... 100k
um tempo pro vector e um tempo pra lista
fazer um grafico que mostre a diferença de tempos

# %%
#include <iostream>
#include <vector>
#include <iterator>
#include <sstream>

using namespace std;

template <class T>
void insertion_sort(vector<T> &vec){
	for(int i=0;i<vec.size();i++){
		T cur_value=vec[i];
		int j=i-1;
		while (j>=0 && vec[j]>cur_value){
			vec[j+1]=vec[j];
			j=j-1;
		}
		vec[j+1]=cur_value;
	}
}
template <class T>
void print (vector<T> &vec){
	std:: copy(vec.begin(),vec.end(),ostream_iterator<T>(cout," "));
	cout<<endl;
}

int main(){
	vector<float> v = {7.1,4,2,0,9};
	print(v);
	insertion_sort<float>(v);
	print(v);
	
	return 0;
}
