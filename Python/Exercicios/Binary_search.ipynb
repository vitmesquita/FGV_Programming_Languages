# %%
def binary_search(valor,A):
    metade1=[A[int(len(A)/2):]]
    metade2=[A[:int(len(A)/2)]]
    index=0
    if A[int(len(A)/2)]>[valor]:
        return binary_search(valor,metade1)
    elif A[int(len(A)/2)]<[valor]:
        return binary_search(valor,metade2)
    else:
        return int(len(A)/2)

# %%
A=[3,4,7]

# %%
A=[3]
