# %% [markdown]
# 1 - Dadas uma lista qualquer, como a do exemplo abaixo:

# %%
lista = [1,2,3,'4',5,6.3,7.4 + 2j,"123",[1,2,3], 93, "98", (1,2,3,'4')]

# %% [markdown]
# Crie uma função recursiva para imprimir o antecessor e o sucessor de cada elemento de uma lista:
# + Caso este elemento seja inteiro, imprimir o valor;
# + Caso seja uma string, imprimir o inteiro correspondente;
# + Caso seja um real, imprima a parte inteira;
# + Caso seja um imaginário, imprima a parte inteira e real;
# + Caso seja uma sequência, aplique as regras acima para cada elemento da sequência.

# %%
def recursiva(a):
    for x in [1,2,3,'4',5,6.3,7.4 + 2j,"123",[1,2,3], 93, "98", (1,2,3,'4')][1:12]:
        if type(x)==int:
            print(x)
        elif type(x)==str:
            print(int(x))
        elif type(x)==complex:
            print(int(x.real))
        else:
            print(list(recursiva(x))
    for y in [1,2,3,'4',5,6.3,7.4 + 2j,"123",[1,2,3], 93, "98", (1,2,3,'4')][0:11]:
        if type(x)==int:
            print(x)
        elif type(x)==str:
            print(int(x))
        elif type(x)==complex:
            print(int(x.real))
        else:
            print(list(recursiva(y))
# Out:
#   File "<ipython-input-45-649de1d6e758>", line 11
#     for y in [1,2,3,'4',5,6.3,7.4 + 2j,"123",[1,2,3], 93, "98", (1,2,3,'4')][0:11]:
#                                                                                   ^
# SyntaxError: invalid syntax

# %%
lista

# %% [markdown]
# 2 - Crie uma função, ou conjunto de funções, para exibir por extenso o valor de qualquer número inteiro até 1000.
# Exemplo:
#
#     print(imprime_extenso(234))
#     > 'duzentos e trinta e quatro'

# %%
def extenso(a):
    cont=0
    numero=str(a)
    alg=len(a)
    if cont ==0 :
        if numero[cont]==0:
            s1='zero'
        elif numero[cont]==1 and numero[cont+1]==0 and numero[cont+2]==0 and numero[cont+3]==0:
            s1='mil'
        elif numero[cont]==1 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='cem'
        elif numero[cont]==1 and numero[cont+1]==0:
            s1='dez'
        elif numero[cont]==2 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='duzentos'
        elif numero[cont]==2 and numero[cont+1]==0:
            s1='vinte'
        elif numero[cont]==2:
            s1='dois'
        elif numero[cont]==3 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='trezentos'
        elif numero[cont]==3 and numero[cont+1]==0:
            s1='trinta'
        elif numero[cont]==3:
            s1='tres'
        elif numero[cont]==4 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='quatrocentos'
        elif numero[cont]==4 and numero[cont+1]==0:
            s1='quarenta'
        elif numero[cont]==4:
            s1='quatro'
        elif numero[cont]==5 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='quinhentos'
        elif numero[cont]==5 and numero[cont+1]==0:
            s1='cinquenta'
        elif numero[cont]==5:
            s1='cinco'
        elif numero[cont]==6 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='seiscentos'
        elif numero[cont]==6 and numero[cont+1]==0:
            s1='sessenta'
        elif numero[cont]==6:
            s1='seis'
        elif numero[cont]==7 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='setecentos'
        elif numero[cont]==7 and numero[cont+1]==0:
            s1='setenta'
        elif numero[cont]==7:
            s1='sete'
        elif numero[cont]==8 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='oitocentos'
        elif numero[cont]==8 and numero[cont+1]==0:
            s1='oitenta'
        elif numero[cont]==8:
            s1='oito'
        elif numero[cont]==9 and numero[cont+1]==0 and numero[cont+2]==0:
            s1='novecentos'
        elif numero[cont]==9 and numero[cont+1]==0:
            s1='noventa'
        elif numero[cont]==9 or 
            s1='nove'

# %%
a=str(200)
a
# Out:
# '200'

# %%
a
# Out:
# 3

# %% [markdown]
# 3- Em alguns lugares é comum lembrar um número do telefone associando seus dígitos a letras. Dessa maneira a expressão MY LOVE significa 69 5683. Claro que existem alguns problemas, uma vez que alguns números de telefone não formam uma palavra ou uma frase e os dígitos 1 e 0 não estão associados a nenhuma letra.
#
# Sua tarefa é ler uma expressão e encontrar o número de telefone correspondente baseado na tabela abaixo. Uma expressão é composta por letras maiúsculas (A-Z), hifens (-) e os números 1 e 0.
#
# Letras  ->  Número
# ABC    ->  2
# DEF    ->  3
# GHI    ->  4
# JKL    ->  5
# MNO    ->  6
# PQRS    ->  7
# TUV    ->  8
# WXYZ   ->  9
#
# Entrada
#
# A entrada consiste de um conjunto de expressões. Cada expressão está sozinha em uma linha e possui C caracteres, onde 1 ≤ C ≤ 30. A entrada é terminada por fim de arquivo (EOF).
#
# Saída
#
# Para cada expressão você deve imprimir o número de telefone correspondente.
#
# Exemplo de entrada:
#
# 1-HOME-SWEET-HOME
# MY-MISERABLE-JOB
#
# Saída correspondente:
#
# 1-4663-79338-4663
# 69-647372253-562

# %% [markdown]
# 4- Dada um texto em formato string, encontre todas as palavras pertencentes a esta string que contenham uma determinada letra, passada como parâmetro.
