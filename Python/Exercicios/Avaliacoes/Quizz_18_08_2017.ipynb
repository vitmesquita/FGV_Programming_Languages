# %% [markdown]
# 1 - Dada a lista:

# %%
lista = [1,2,3,'4',5,6.3,7.4 + 2j,"123",[1,2,3], 93, "98"]

# %% [markdown]
# Crie um código para imprimir o antecessor e o sucessor de cada elemento de uma lista:
# + Caso este elemento seja inteiro, imprimir o valor;
# + Caso seja uma string, imprimir o inteiro correspondente;
# + Caso seja um real, imprima a parte inteira;
# + Caso seja um imaginário, imprima a parte inteira e real;
# + Caso seja uma sequência, aplique as regras acima para cada elemento da sequência.

# %%
cont=0
while cont != len(lista)+1:
    if cont==0:
        if type(lista[cont])== int:
            print(lista[cont])
            print(lista[cont+1])
        elif type(lista[cont])== str:
            print(int(lista[cont]))
            print(lista[cont+1])
        elif type(lista[cont])== float:
            print(int(lista[cont]))
            print(lista[cont+1])
        elif type(lista[cont])== complex:
            print(int(lista[cont].real))
            print(lista[cont+1])
        elif type(lista[cont])== list:
            #fazer o mesmo processo
    elif:
        if cont==len(lista):
            if type(lista[cont])== int:
                print(lista[cont])
                print(lista[cont-1])
            elif type(lista[cont])== str:
                print(int(lista[cont]))
                print(lista[cont-1])
            elif type(lista[cont])== float:
                print(int(lista[cont]))
                print(lista[cont-1])
            elif type(lista[cont])== complex:
                print(int(lista[cont].real))
                print(lista[cont-1])
            elif type(lista[cont])== list:
                #fazer o mesmo processo
    else:
        if type(lista[cont])== int:
            print(lista[cont])
            print(lista[cont+1])
            print(lista[cont-1])
        elif type(lista[cont])== str:
            print(int(lista[cont]))
            print(lista[cont+1])
            print(lista[cont-1])
        elif type(lista[cont])== float:
            print(int(lista[cont]))
            print(lista[cont+1])
            print(lista[cont-1])
        elif type(lista[cont])== complex:
            print(int(lista[cont].real))
            print(lista[cont+1])
            print(lista[cont-1])
        elif type(lista[cont])== list:
            #fazer o mesmo processo
        
            
            
            
            
            print(lista[cont-1])
# Out:
#   File "<ipython-input-32-75c492b7c9f6>", line 18
#     elif:
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# 2 - Os fatores primos de 13195 são 5, 7, 13 e 29. Qual o maior fator primo de 600851475143?
# https://projecteuler.net/problem=3

# %%
numbers=range(2,20000)
primos=[]
for x in numbers:
    k=1
    for c in range(2,x):
            if x % c == 0:
                k=0
                break

    if k==1:
        primos.append(x)
    else:
        continue
fatores=[]
for j in primos:
    if  600851475143 % j == 0:
        fatores.append(j)
    else:
        continue
print(fatores[-1])
# Out:
# 6857

# %% [markdown]
# 3- Crie um programa que imprima os números de 1 a 100, mas nos múltiplos de 3 imprima “Fizz” em vez do  número e nos múltiplos de 5 imprima “Buzz”. Para os números que são múltiplos de tanto 3 como 5, imprima “FizzBuzz”.

# %%
for v in range(1,100):
    if v % 3 == 0 and v % 5 == 0:
        print('FizzBuzz')
    if v % 3 == 0:
        print('Fizz')
    elif v % 5 == 0:
        print ('Buzz')
    else:
        print (v)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# Fizz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# Fizz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# Fizz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# Fizz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# Fizz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# Fizz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz

# %% [markdown]
# 4- Usando a biblioteca "random", crie um programa para calcular a média da soma de dois dados de 6 faces (D6) em 10000 lançamentos.

# %%
import random

# %%
soma=0
for y in range(10000):
    dado=random.randint(1,6)
    soma=soma+dado
print(soma/10000)
# Out:
# 3.5021

# %%
int(4**1/2)
# Out:
# 2
