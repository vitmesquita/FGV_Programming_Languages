# %%
c=input()
numbers=[]
for k in range(int(c)):
    n=input()
    numbers.append(n)
    print(numbers)
for j in numbers:
    print(j)
    c=int(j[0])**int(j[2])
    print(c)
    c=str(c)
    print(c)
    print(len(c))
    print(len(str(int(j[0])**int(j[2]))))
# Out:
# 4
# 1 1
# 2 10
# 3 9
# 100 100
# 1
# 1
# 5
# 1

# %% [markdown]
#  print(len(str(int(j[2])**int(j[0]))))
