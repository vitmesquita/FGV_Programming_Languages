# %%
def circulo(R):
    n=3.14159
    r=float(R)
    area=n*r**2
    print('A={:.4f}'.format(area))

# %%
circulo(100.64)
# Out:
# A=31819.3103

# %%
def somasim(a,b):
    soma=0
    soma=soma+a+b
    print(soma)

# %%
somasim(0,0)
# Out:
# 0

# %%
def prod(a,b):
    prod=1
    prod=prod*a*b
    print('PROD = {}'.format(prod))

# %%
prod(5,6)
# Out:
# PROD=30

# %%
prod(-8,5)
# Out:
# PROD=-40

# %%
def average1(a,b):
    s=(a*3.5+b*7.5)/11
    print('MEDIA = {:.5f}'.format(s))

# %%
average1(5,5)
# Out:
# MEDIA=5.00000
