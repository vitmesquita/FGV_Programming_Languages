# %%
texto= '''João amava Teresa que amava Raimundo
que amava Maria que amava Joaquim que amava Lili
que não amava ninguém.
João foi para os Estados Unidos, Teresa para o convento,
Raimundo morreu de desastre, Maria ficou para tia,
Joaquim suicidou-se e Lili casou com Pinto Fernandes
que não tinha entrado na história'''

# %%
print(texto)
# Out:
# João amava Teresa que amava Raimundo
# que amava Maria que amava Joaquim que amava Lili
# que não amava ninguém.
# João foi para os Estados Unidos, Teresa para o convento,
# Raimundo morreu de desastre, Maria ficou para tia,
# Joaquim suicidou-se e Lili casou com Pinto Fernandes
# que não tinha entrado na história

# %%
a
# Out:
# ['João',
#  'amava',
#  'Teresa',
#  'que',
#  'amava',
#  'Raimundo',
#  'que',
#  'amava',
#  'Maria',
#  'que',
#  'amava',
#  'Joaquim',
#  'que',
#  'amava',
#  'Lili',
#  'que',
#  'não',
#  'amava',
#  'ninguém.',
#  'João',
#  'foi',
#  'para',
#  'os',
#  'Estados',
#  'Unidos,',
#  'Teresa',
#  'para',
#  'o',
#  'convento,',
#  'Raimundo',
#  'morreu',
#  'de',
#  'desastre,',
#  'Maria',
#  'ficou',
#  'para',
#  'tia,',
#  'Joaquim',
#  'suicidou-se',
#  'e',
#  'Lili',
#  'casou',
#  'com',
#  'J.',
#  'Pinto',
#  'Fernandes',
#  'que',
#  'não',
#  'tinha',
#  'entrado',
#  'na',
#  'história']

# %%
import string

# %%
b=[token.strip() for token in a ]
b
# Out:
# ['João',
#  'amava',
#  'Teresa',
#  'que',
#  'amava',
#  'Raimundo',
#  'que',
#  'amava',
#  'Maria',
#  'que',
#  'amava',
#  'Joaquim',
#  'que',
#  'amava',
#  'Lili',
#  'que',
#  'não',
#  'amava',
#  'ninguém.',
#  'João',
#  'foi',
#  'para',
#  'os',
#  'Estados',
#  'Unidos,',
#  'Teresa',
#  'para',
#  'o',
#  'convento,',
#  'Raimundo',
#  'morreu',
#  'de',
#  'desastre,',
#  'Maria',
#  'ficou',
#  'para',
#  'tia,',
#  'Joaquim',
#  'suicidou-se',
#  'e',
#  'Lili',
#  'casou',
#  'com',
#  'J.',
#  'Pinto',
#  'Fernandes',
#  'que',
#  'não',
#  'tinha',
#  'entrado',
#  'na',
#  'história']

# %%
for x in range(len(b)):
    lista=b.count(b[x])
    print(lista)
# Out:
# 2
# 6
# 2
# 6
# 6
# 2
# 6
# 6
# 2
# 6
# 6
# 2
# 6
# 6
# 2
# 6
# 2
# 6
# 1
# 2
# 1
# 3
# 1
# 1
# 1
# 2
# 3
# 1
# 1
# 2
# 1
# 1
# 1
# 2
# 1
# 3
# 1
# 2
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 6
# 2
# 1
# 1
# 1
# 1

# %%
len(b)
# Out:
# 52

# %%
lista[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-09bfed834fa2> in <module>()
# ----> 1 lista[4]
#
# TypeError: 'int' object is not subscriptable
