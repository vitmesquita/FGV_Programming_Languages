# %% [markdown]
# FGV - Escola de Matemática Aplicada
# ==
# Curso de Verão - Introdução à Programação com a Linguagem Python
# --

# %% [markdown]
# #### Classes

# %%
class Inutil:
    pass

# %%
dir()

# %%
lista=['a','b']
dict(lista[1])==4

# %%
Inutil

# %%
alguma_instancia = Inutil()

# %%
type(alguma_instancia)

# %%
alguma_instancia

# %%
class MyClass:
    """
    Aqui eu vou colocar
    uma string que define as
    principais informações sobre
    a classe que estou criando
    """
    
    atributo_da_classe = 1234
    outro_atributo = 5678
    
    def metodo_da_classe(self):
        return 'Olá povo!'

# %% [markdown]
# 'funçao dentro de classe = método da classe
#
#
#
# 'valor dentro da classe = atributo da classe'

# %%
x = MyClass()
y = MyClass()

# %%
x

# %%
x.atributo_da_classe

# %%
x.outro_atributo

# %%
x.metodo_da_classe

# %%
x.metodo_da_classe()

# %%
x.atributo_da_classe

# %%
x.atributo_da_classe = 4321

# %%
x.atributo_da_classe

# %%
y.atributo_da_classe

# %%
x.atributo_da_classe

# %%
x.novo_atributo = "qualquer coisa nova"

# %%
type(x)

# %%
z = MyClass()

# %%
dir(x)

# %%
z=MyClass()

# %%
dir(z)

# %%
q= [1,2,3]

# %%
q.append(2)
q

# %%
def outro():
    print('mudei')

# %%
q.append = outro

# %% [markdown]
# instanciar= atribuir a classe uma variavel

# %% [markdown]
# z nao possui o "novo atributo" pois isso foi dado apena em x

# %%
class MyComplex:
    def __init__(self, realpart, imagpart):
        self.r = realpart
        self.i = imagpart

# %%
z = MyComplex(2,-4)
j = MyComplex(13,12)

# %%
z.r

# %%
z.i

# %%
z.novo_atributo = 'uma nova coisa'

# %%
z.novo_atributo

# %%
j.i

# %%
j.r

# %%
class Retangulo:
    def inverte(self):
        self.largura, self.comprimento = self.comprimento, self.largura
    
    def __init__(self, ladoa, ladob):
        self.comprimento = ladoa
        self.largura = ladob
        self.area = ladoa * ladob
        self.perimetro = 2 * (ladoa+ladob)
        if self.largura > self.comprimento:
            self.inverte()

# %%
class Triangulo:
    def __init__(self,lado1,lado2,lado3):
        self.lado1=lado1
        self.lado2=lado2
        self.lado3=lado3
        
    def __repr__(self):
        return('Tririririr')
    
    def tipo(self):
        if self.lado1==self.lado2 and self.lado1==self.lado3:
            print('Equilátero')
        elif self.lado1==self.lado2 or \
             self.lado2==self.lado3 or \
             self.lado3==self.lado1:
            print('Isósceles')
        else:
            print('Escaleno')

# %% [markdown]
# self é referencia a propria instancia, ou seja, ao por self como parametro, usa-se o que foi definido no init, que é onde cria-se a possibilidade de parametro

# %%
tri=Triangulo(8,8,2)
print(tri)

# %%
tri.tipo()

# %%
meu_retangulo = Retangulo(10,50)

# %%
meu_retangulo.area

# %%
meu_retangulo.largura

# %%
meu_retangulo.inverte()

# %%
meu_retangulo.comprimento

# %%
dir(meu_retangulo)

# %%
meu_retangulo.__repr__

# %%
print(meu_retangulo)

# %%
class NovaClasse:
    prop1 = 'texto'

# %%
x = NovaClasse()
y = NovaClasse
print(type(x))
print(type(y))

# %%
print(x.prop1)
x.prop1 = 'Mudei'
print(x.prop1)

# %%
a = NovaClasse()
a.prop1

# %%
y.prop1 = 'mudei definitivamente'

# %%
b = NovaClasse()
b.prop1

# %%
x.prop1

# %%
NovaClasse.prop1

# %%
x.prop1

# %%
a.prop1

# %%
c = y()

# %%
c.prop1

# %%
dir(NovaClasse)

# %%
class Dog:
    def __init__(self, name, raca='vira lata'):
        self.name = name
        self.raca = raca
        self.tricks = []

    def add_trick(self, trick):
        if not trick in self.tricks:
            self.tricks.append(trick)

# %%
d = Dog('Fido','Pastor Alemao')
e = Dog('Buddy','Cocker')
f = Dog('Rex')

# %%
d.name

# %%
f.raca

# %%
d.add_trick('Rolar')
e.add_trick('Fingir-se de morto')

# %%
d.tricks

# %%
d.add_trick('Pedir Comida')

# %%
d.name

# %%
d.raca

# %%
d.tricks

# %%
e.tricks

# %%
f = Dog('Rex','Doberman')

# %%
f.name

# %%
f.raca

# %%
f.add_trick('Latir para ladroes')
f.tricks

# %%
import time
class SuperDog(Dog):
    
    def __init__(self, name, raca):
        Dog.__init__(self,name, raca)
        self.comida = False
        self.adestrado = False
        self.ultima_refeicao = time.time()
        
        
    def esta_com_fome(self):
        if time.time() - self.ultima_refeicao < 20:
            print('Não')
        else:
            print('Sim, a última refeição foi')
            print('há {:.2f} min'.format((time.time() - self.ultima_refeicao)/60))
    
    def adestra(self):
        self.adestrado = True
    
    def alimenta(self):
        self.ultima_refeicao = time.time()

# %%
f = SuperDog('Raghu','Labrador')

# %%
f.esta_com_fome()

# %%
f.esta_com_fome()

# %%
f.alimenta()

# %%
f.esta_com_fome()

# %%
f.tricks

# %%
f.adestrado

# %%
f.adestra()

# %%
f.adestrado

# %% [markdown]
# Exercício com Classes:
# Crie uma classe "Automovel", com propriedades:
# - Modelo (atributo) --> O modelo do Automovel
# - Autonomia (método)  --> Deve retornar quantos km ele pode andar
# - Nível do tanque (método e atributo) --> Deve retornar o número de litros do tanque
# - Capacidade do tanque (Atributo) --> Quantidade de litros do tanque "cheio", capacidade máxima
# - Consumo (atributo) --> Um valor representando o consumo em km por litro
# - Abastece (método) --> Acrescenta um numero de litros de combustível ao tanque, até, no máximo, sua capacidade
# - Anda (método) --> Faz o automóvel andar um número específico de km
# - Odometro --> (atributo) Retorna o número total de km andados
# - Odometro parcial (atributo) --> Retorna o número de km andados desde o ultimo abastecimento

# %%
class Automovel:
    def __init__(self,modelo,consumo,cap_tanque,capacidade):
        self.modelo=modelo
        self.cap_tanque=cap_tanque
        self.capacidade=capacidade
        self.consumo=consumo
        self.odometro=0
        self.odometro_p=0
        self.n_tanque=3
    def autonomia(self):
        return self.consumo*self.n_tanque
    def niveltanque(self):
        return self.n_tanque
    def abastece(self):
        self.n_tanque=self.cap_tanque
    def anda(self,km):
        if km/self.n_tanque < self.n_tanque:

# %%
class Auto:
    def __init__(self, modelo, consumo, capacidade_tanque):
        self.modelo = modelo
        self.consumo = consumo
        self.capacidade_tanque = capacidade_tanque
        self.odometro = 0
        self.odometro_parcial = 0
        self.combustivel = 0
        
    def anda(self,km):
        if km/self.consumo < self.combustivel:
            self.combustivel -= (km/self.consumo)
            self.odometro += km
            self.odometro_parcial += km
        else:
            print('Você só pode andar {0:.2f} Km'.format(self.autonomia()))

    def abastece(self, litros):
        self.falta = self.capacidade_tanque - self.combustivel
        if litros > self.falta:
            print('Você só pode abastecer {0:.2f} litros'.format(self.falta))
        else:
            self.odometro_parcial = 0
            self.combustivel += litros
            print('Abastecemos {0:.2f} litros'.format(litros))
            print('Tanque possui {0:.2f} litros'.format(self.combustivel))

    def autonomia(self):
        self.atnm = self.combustivel*self.consumo
        print('A autonomia é de {0:.2f} Km'.format(self.atnm))
        return self.atnm
    
    def nivel_tanque(self):
        print('O tanque contém {0:.2f} litros'.format(self.combustivel))
    
    def mostra_odometro(self):
        print('Odômetro parcial: {0:.2f}'.format(self.odometro_parcial))
        print('Odômetro total: {0:.2f}'.format(self.odometro))

# %%
meucarro = Auto('Nissam',9,40)

# %%
meucarro.anda(240)

# %%
meucarro.abastece(20)

# %%
meucarro.autonomia()

# %%
meucarro.anda(240)

# %%
meucarro.anda(100)

# %%
meucarro.mostra_odometro()

# %%
meucarro.abastece(20)

# %%
meucarro.autonomia()

# %%
meucarro.mostra_odometro()

# %%
class Aleatorio:
    def __init__(self,maximo):
        self.max=maximo
    def __iter__(self):
        self.count=0
        return self
    def __next__(self):
        self.count+=1
        valor = random.random()
        if valor > 0.95 or valor < 0.05 or self.count> self.max:
            raise StopIteration
        return valor

# %%
import random
y=Aleatorio(10)

# %%
list(y)
# Out:
# [0.4354873845937959,
#  0.25255973106431884,
#  0.30424020498050386,
#  0.17938619601855188,
#  0.848437049089254,
#  0.24280100768323665,
#  0.1269550876121882,
#  0.8213786980869425,
#  0.16688498157046994,
#  0.6664988461560158]

# %%
d20v=[ random.randrange(1,6) for b in range(1000)]
dic={'um':0,'dois':0,'tres':0,'quatro':0,'cinco':0}
for k in d20v:
    if k==1:
        dic['um'] += 1
    if k==2:
        dic['dois'] += 1
    if k==3:
        dic['tres'] += 1
    if k==4:
        dic['quatro'] += 1
    if k==5:
        dic['cinco'] += 1
print(dic)
# Out:
# {'cinco': 202, 'dois': 176, 'tres': 211, 'um': 197, 'quatro': 214}

# %%
import string

# %%
list(range(1,6))+[5]
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
{x:y for y,x in dic.items()}
# Out:
# {176: 'dois', 197: 'um', 202: 'cinco', 211: 'tres', 214: 'quatro'}

# %%
dic
# Out:
# {'cinco': 202, 'dois': 176, 'quatro': 214, 'tres': 211, 'um': 197}

# %%
dic.items()
# Out:
# dict_items([('cinco', 202), ('dois', 176), ('tres', 211), ('um', 197), ('quatro', 214)])

# %%
dic.keys()
# Out:
# dict_keys(['cinco', 'dois', 'tres', 'um', 'quatro'])

# %%
dic.values()
# Out:
# dict_values([202, 176, 211, 197, 214])

# %%
from collections import OrderedDict

# %%
x = OrderedDict([('um',1),('dois',2),('tres',3)])

# %%
x
# Out:
# OrderedDict([('um', 1), ('dois', 2), ('tres', 3)])

# %%
for v in x:
    print(v)
# Out:
# um
# dois
# tres
