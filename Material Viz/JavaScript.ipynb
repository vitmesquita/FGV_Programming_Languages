# %%
var respostas=[
"melhor nao",
"faz sim apoio total grl pwr",
"eh doida coitada",
"nao me faz responde isso nao",
"ja devia ter feito ok"
]

respostas[Math.floor(Math.random()*5)]

# %%
var age=11
var accomp=false

var result=(age>=13)||(age<13 && accomp)

# %%
var insultos=[
"ridicula",
"falsaaa",
"sonsa",
"chacotaa"
]

insultos[Math.floor(Math.random()*(insultos.length))]

var partecorpo=[
"barriga",
"testa",
"bunda",
"cara",
]

var animal=[
"leao marinho",
"peixe",
"camelo",
"calango",
]

var parteanimal=[
"barriga",
"boca",
"nariz",
"olho",
]

var frase=["Sua",partecorpo[Math.floor(Math.random()*4)],"é mais",insultos[Math.floor(Math.random()*4)],"que",parteanimal[Math.floor(Math.random()*4)],"de",animal[Math.floor(Math.random()*4)]].join(" ")

frase= "Sua "+partecorpo[Math.floor(Math.random()*4)]+" é mais "+insultos[Math.floor(Math.random()*4)]+" que "+parteanimal[Math.floor(Math.random()*4)]+" de "+animal[Math.floor(Math.random()*4)];

# %%
var numeros=[3,2,1]
numeros.join(" é maior que ")

# %%
var myCrazyObject = {
"name": "A ridiculous object",
"some array": [7, 9, { purpose: "confusion", number: 123 }, 3.3],
"random animal": "Banana Shark"
};

myCrazyObject["some array"][2]["number"]

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
	var name = "José";
	if (name==="Vitoria" || name==="Vit"){
		console.log("Hello me!")
	}else if (name==="Maria"){
		console.log("Hello Mom")
	}else if (name==="José"){
		console.log("Hello Dad")
	}else if (name==="Giovanni"){
		console.log("Hey babe")
	}else {
		console.log("Hello Stranger!")
	}
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
	for (var x =3 ; x<10000;  x=x*3){
		console.log(x);
	}
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
	var x=3
	while (x<10000){
		console.log(x);
		x=x*3
	}
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
		var animals=["Gato","Peixe","Cobra"];
		var i=0
	while(i<animals.length){
		animals[i]=animals[i]+" "+"Incrivel";
		i++
	}
	console.log(animals);
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
		var alfabeto="qwertyuiopasdfghjklzxcvbnm"
		var stringnova=""
		var i=0
		while(i<6){
			stringnova=stringnova+alfabeto[Math.floor(Math.random()*alfabeto.length)]
			console.log(stringnova)
			i++
		}
		console.log(stringnova)
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
		var frase="Aprendendo JavaScript";
		var numero=frase.length;
		for (var i=0;i<numero;i++){
			if (frase[i]==="a"){
				frase=frase.replace("a","4");
			}else if (frase[i]==="e"){
				frase=frase.replace("e","3");
			}else if (frase[i]==="o"){
				frase=frase.replace("o","0");
			}
			//;
		}
		console.log(frase);
	</script>
</body>
</html>

# %%
<!DOCTYPE html>
<html>
<head>
	<title>My first proper HTML page</title>
</head>

<body>
	<p>My first web page.</p>
	<script>
		var palavras=[
		"abelha",
		"gato",
		"panqueca",
		"pudim"
		]
		var palavra= palavras[Math.floor(Math.random()* palavras.length)]
		var resposta=[];
		for(var i=0 ; i < palavra.lenght; i++){
			resposta[i]= "_";
		}
		var restantes = palavra.lenght;

		while (restantes>0){
			alert(resposta.join(" "));
			var chute = prompt("Escolha uma letra!")
			if (chute === null){
				break
			} else if (chute.lenght!==1){
				alert("Por favor, escolha uma letra")
			} else{
				for(j=0 ; j < palavra.lenght ; j++){
					if (palavra[j]===chute){
						resposta[j]=chute;
						restantes--
					}else{
						alert("Errado!");
					}
				}
			}
		alert(respota.join(""))
		alert("PARABENSS! A resposta era "+palavra)
		}
	</script>
</body>
</html>
